# %% [markdown]
# # Fine-tune Whisper за македонски

# %% [markdown]
# ## 1. GPU

# %%
# !nvidia-smi -L

# %% [markdown]
# ## 2. Проект + зависности

# %%
# %cd /content
# !rm -rf vezilka
# !git clone -q https://github.com/ristomanchev/vezilka.git
# %cd vezilka
# !pip install -q -U transformers datasets accelerate evaluate jiwer soundfile librosa

# %% [markdown]
# ## 3. Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 4а. whisper-small + FLEURS
#
# WER 52.9 → 36.1 (нормализиран).

# %%
# !python train_whisper.py
# Out:
# ...
#
#
#
# [extra] fleurs: 2337 clips
# our train=573  test=99  extra sources=1
# TOTAL train examples: 2910
#
# 2026-09-02 09:40:02.866076: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# === baseline eval (before fine-tuning) ===
# [transformers] Passing `generation_config` together with generation-related arguments=({'suppress_tokens', 'begin_suppress_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ...

# %% [markdown]
# ## 4б. whisper-medium + SILVER + FLEURS
#
# | чекор | WER норм. | WER raw |
# |---|---|---|
# | baseline | 47.0 | 53.4 |
# | 250 | 27.1 | 33.9 |
# | 500 | 25.3 | 32.0 |
# | 750 | 25.1 | 31.6 |

# %%
# !OUTPUT_DIR=/content/drive/MyDrive/whisper-mk-run INCLUDE_SILVER=1 BASE_MODEL=openai/whisper-medium MAX_STEPS=2000 python train_whisper.py

# %% [markdown]
# ## 5. Тест на моделот

# %%
M = '/content/drive/MyDrive/whisper-mk-run'
# !python transcribe.py dataset_v2_new/clips/dvtzhgajmmx_000000.wav --hf $M --label
# !python transcribe.py dataset_v2_new/clips/db5mzr_xbog_000012.wav --hf $M --label
